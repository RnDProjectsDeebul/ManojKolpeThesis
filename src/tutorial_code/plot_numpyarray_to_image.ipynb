# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
data = np.load("/home/latai/Documents/Master_thesis/Data/seq-04_formatted/disparity_online.npy")

# %%
path = "/home/latai/Documents/Master_thesis/Data/seq-04_formatted/result/"

# %%
data.shape
# Out:
# (65, 480, 640)

# %%
for i, j in enumerate(data):
    plt.imshow(j)
    plt.savefig(path+str(i)+'.png')
    plt.show

# %%
pil_img = Image.fromarray((data[0] * 255).astype('uint8'), mode='L')

# %%
 = (pil_img * 255).astype(np.uint8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-3b4e2a89152a> in <module>
# ----> 1 pil_img = (pil_img).astype(np.uint8)
#
# ~/anaconda3/envs/latai/lib/python3.7/site-packages/PIL/Image.py in __getattr__(self, name)
#     546             )
#     547             return self._category
# --> 548         raise AttributeError(name)
#     549
#     550     @property
#
# AttributeError: astype

# %%
pil_img.show()

# %%
Image.fromarray(data[0]).show()
