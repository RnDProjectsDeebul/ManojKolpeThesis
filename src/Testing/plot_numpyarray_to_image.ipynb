# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("/home/latai/Documents/Master_thesis/Data/seq-03_formated_manoj/result/disparity.npy")

# %%
path = "/home/latai/Documents/Master_thesis/Data/seq-03_formated_manoj/result/"

# %%
data.shape
# Out:
# (44, 480, 640)

# %%
for i, j in enumerate(data):
    plt.imshow(j)
    plt.savefig(path+str(i)+'.png')
    plt.show
